# %% [markdown]
# ## Einführung in Matplotlib

# %%
#Zunächst importieren wir Matplotlib und numpy

import numpy as np 
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()  # Kreiert eine Figur mit einer Achse
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plotte Daten auf die Achse

# %% [markdown]
# **Damit der Output nicht gezeigt wird, lässt sich plt.show() verwenden**

# %%
fig, ax = plt.subplots() 
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  
plt.show()

# %% [markdown]
# **Matplotlib ermöglicht es einfacher Plots zu erstellen:**
#
# * Nutzt die aktuelle Achse für den Plot
#
# * Existiert eine Achse noch nicht dann wird diese erstellt

# %%
#Der obere Plot vereinfacht

plt.plot([1,2,3,4],[1, 4, 2, 3])
plt.show()

# %% [markdown]
# ## Aufbau eines Plots

# %% [markdown]
# ### Figur
#
# * gibt den Rahmen der Figur vor
# * beinhaltet die einzelnen Achsen
# * kann beliebig viele Achsen beinhalten, jedoch meist mindestens einzelnen
# * Achsen können mit dem Plot erstellt werden oder im Nachhinein hinzugefügt werden

# %%
#Kreieren einer Figur ohne Achse

fig = plt.figure()

# %%
#Eine Figur mit einer Achse
fig, ax = plt.subplots()

# %%
#Eine Figur mit einem 2x2 Grid als Achse
fig, axs = plt.subplots(2, 2)

# %% [markdown]
# ### Axes
#
# * Axes sind das, was man sich als Plot vorstellt
# * Eine Figur kann mehrere Axes als Objekt beinhalten, jedoch kann jede Axes nur in einem Plot vorhanden sein
# * Axes beinhalten einzelne Axis (in 2-D 2 und in 3-D 3)
# * Jede Axes hat einen Namen dieser lässt sich über plt.xlabel() und plt.ylabel() bestimmen

# %% [markdown]
# ### Axis
#
# *  bestimmt die Daten Limits
# * bestimmt die einzelnen Ticks (Abschnitte)

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  #Plotte die Gerade indem wir sowohl der x-Achse als auch der y-Achse die gleichen Daten übergeben, 
#Kreiere hierfür die nicht existente Achse
plt.plot(x, x**2, label='quadratic')  #plotte auf die selbe Achse
plt.plot(x, x**3, label='cubic') #usw.
plt.xlabel('x Achse') #Bennene die x-Achse
plt.ylabel('y Achse') #Bennene die y-Achse
plt.title("Beispiel Plot") #Gebe dem Plot einen Namen
plt.legend() #Lasse die Legende ausgeben
plt.show()

# %% [markdown]
# * Achsen Limits lassen sich über .set_xlim() bzw. y_lim setzen
# * Einzelne Punkte lassen sich über scatter einzeichnen

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
plt.xlim(0.5, 4.5)
plt.show()

# %% [markdown]
# **Anmerkung:**
#
# * Punkte außerhalb der Achsen-Limits werden ignoriert
# * Setzt man das Limit nicht so werden die Achsen so angepasst, dass alle Daten im Plot sind

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')

plt.show()
